# %% [markdown]
# # Sample Analysis Notebook
#
# This notebook demonstrates the template structure. Delete or modify as needed.
#
# **Changelog**
# - 2026-01-27: Initial template notebook

# %% [markdown]
# ## Preliminaries

# %% [markdown]
# ### Dependency notebooks

# %% [markdown]
# Link to notebooks/scripts this analysis depends on, e.g.:
# - `XX-2026-01-20_preprocessing.ipynb` — raw data → processed AnnData

# %% [markdown]
# ### Library imports

# %% [markdown]
# `autoreload` to re-load packages.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# The actual imports.

# %%
import scanpy as sc

from myanalysis import FilePaths

# %% [markdown]
# ### General settings

# %% [markdown]
# Define constants, figure settings, etc.

# %%
sc.settings.set_figure_params(dpi=100, frameon=False)

# %% [markdown]
# ### Function definitions

# %% [markdown]
# Any utility functions you may need in this notebook go here.

# %% [markdown]
# ### Data loading

# %% [markdown]
# Store data in `data/<dataset>/` with subfolders `raw/`, `processed/`, `resources/`, `results/`. Access paths via `FilePaths`:

# %%
print(f"Data directory: {FilePaths.DATA}")
print(f"Figures directory: {FilePaths.FIGURES}")

# %% [markdown]
# ## Main analysis

# %% [markdown]
# Your analysis code goes here. Delete these placeholder cells.
